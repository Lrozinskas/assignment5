# %%
import json
from gensim import corpora, models
import pyLDAvis.gensim_models
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

__author__ = "Luke Rozinskas"
__copyright__ = "Copyright 2023, Westmont College"
__credits__ = ["Luke Rozinskas", "ChatGPT Ai"]
__license__ = "MIT"
__email__ = "lrozinskas@westmont.edu"


# Download the NLTK stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# Specify the path to your watch history file
watch_history_file = '/home/lrozinskas/CS128/Data_folder/history/watch-history.json'

# Read the JSON data
with open(watch_history_file, 'r') as f:
    data = json.load(f)

# Extract titles from the data
titles = [entry['title'] for entry in data]

# Tokenize and preprocess the data, removing stopwords
stop_words = set(stopwords.words('english'))
stop_words.add('watched')

# Modify the filtering condition to exclude individual numbers
tokenized_titles = [word_tokenize(title.lower()) for title in titles]
filtered_tokenized_titles = [
    [word for word in tokens if re.search('[a-zA-Z]', word) and word.isalnum() and word not in stop_words]
    for tokens in tokenized_titles
]

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(filtered_tokenized_titles)
corpus = [dictionary.doc2bow(tokens) for tokens in filtered_tokenized_titles]

# Build the LDA model
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# Print the top words for each topic
topics = lda_model.print_topics(num_words=5)
for topic in topics:
    print(f"Topic {topic[0] + 1}: {topic[1]}")

# Visualize the topics using pyLDAvis
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/lrozinskas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/lrozinskas/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Topic 1: 0.014*"take" + 0.014*"shorts" + 0.013*"first" + 0.008*"food" + 0.007*"nba"
# Topic 2: 0.027*"team" + 0.016*"skip" + 0.015*"fifa" + 0.014*"stephen" + 0.013*"ultimate"
# Topic 3: 0.033*"mlb" + 0.031*"show" + 0.020*"diamond" + 0.014*"dynasty" + 0.013*"world"
# Topic 4: 0.036*"shorts" + 0.030*"f1" + 0.011*"hamilton" + 0.010*"video" + 0.010*"golf"
# Topic 5: 0.033*"nba" + 0.027*"game" + 0.025*"highlights" + 0.020*"lakers" + 0.019*"undisputed"
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el9591407041058743685833513880" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el9591407041058743685833513880_data = {"mdsDat": {"x": [-0.29851622175270554, 0.12018847972430495, 0.0993530823563308, 0.0010456549820036807, 0.07792900469006629], "y": [0.01897072493123233, 0.14457294313956853, 0.10088043382245203, 0.014689891793460764, -0.27911399368671364], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [24.304946048841035, 21.332149570312968, 20.35465502697264, 18.015693879373185, 15.99255547450017]}, "tinfo": {"Term": ["show", "mlb", "game", "nba", "f1", "highlights", "team", "shorts", "lakers", "diamond", "undisputed", "https", "grand", "dynasty", "skip", "prix", "test", "taste", "fifa", "stephen", "take", "ultimate", "player", "world", "hamilton", "perfect", "good", "packs", "shannon", "lebron", "game", "highlights", "lakers", "undisputed", "https", "grand", "prix", "good", "perfect", "race", "dude", "international", "drivers", "match", "james", "suns", "shots", "trick", "x", "broussard", "bob", "davis", "bucks", "warriors", "mike", "playoffs", "nuggets", "kevin", "gm", "mercedes", "shannon", "nba", "finals", "full", "lebron", "taste", "test", "anthony", "sports", "pack", "top", "battle", "best", "vs", "f1", "golf", "first", "di