# %%
import json
from gensim import corpora, models
from pprint import pprint
import pyLDAvis.gensim_models
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download the NLTK stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# Specify the path to your watch history file
watch_history_file = '/home/lrozinskas/CS128/Data_folder/history/watch-history.json'

# Read the JSON data
with open(watch_history_file, 'r') as f:
    data = json.load(f)

# Extract titles from the data
titles = [entry['title'] for entry in data]

# Tokenize and preprocess the data, removing stopwords
stop_words = set(stopwords.words('english'))
stop_words.add('watched')
tokenized_titles = [word_tokenize(title.lower()) for title in titles]
filtered_tokenized_titles = [[word for word in tokens if word.isalnum() and word not in stop_words] for tokens in tokenized_titles]

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(filtered_tokenized_titles)
corpus = [dictionary.doc2bow(tokens) for tokens in filtered_tokenized_titles]

# Build the LDA model
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# Print the top words for each topic
topics = lda_model.print_topics(num_words=5)
for topic in topics:
    print(f"Topic {topic[0] + 1}: {topic[1]}")

# Visualize the topics using pyLDAvis
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/lrozinskas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/lrozinskas/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Topic 1: 0.023*"https" + 0.022*"2021" + 0.019*"grand" + 0.019*"prix" + 0.018*"shorts"
# Topic 2: 0.033*"mlb" + 0.028*"f1" + 0.025*"show" + 0.024*"21" + 0.019*"team"
# Topic 3: 0.025*"diamond" + 0.018*"dynasty" + 0.015*"perfect" + 0.013*"dude" + 0.011*"battle"
# Topic 4: 0.023*"nba" + 0.021*"undisputed" + 0.014*"lebron" + 0.013*"shorts" + 0.013*"shannon"
# Topic 5: 0.022*"game" + 0.019*"nba" + 0.014*"test" + 0.014*"taste" + 0.014*"shorts"
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el9591407040732809603130737362" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el9591407040732809603130737362_data = {"mdsDat": {"x": [-0.09381637531218774, 0.28116474016167103, -0.05947182847224004, -0.14277782146099313, 0.014901285083750174], "y": [0.14607916273089833, -0.04638584308385776, 0.14133330231583752, -0.2457119287538326, 0.004685306790954258], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [23.201446891142684, 21.604353750365508, 20.893867601221228, 17.73995007458437, 16.560381682686213]}, "tinfo": {"Term": ["mlb", "f1", "diamond", "nba", "https", "undisputed", "show", "2021", "21", "team", "game", "grand", "prix", "highlights", "dynasty", "lebron", "test", "perfect", "taste", "shannon", "lakers", "dude", "take", "skip", "full", "first", "good", "fifa", "video", "stephen", "take", "full", "international", "espn", "basketball", "sidemen", "fast", "suns", "anthony", "like", "fc", "spent", "crazy", "davis", "5v5", "euro", "finals", "played", "trash", "frozen", "trade", "breaking", "debut", "fancy", "ohtani", "name", "huge", "roster", "place", "reacting", "jump", "game", "taste", "test", "golf", "part", "first", "food", "lakers", "nba", "time", "bad", "highlights", "2", "shorts", "1", "best", "world", "vs", "5", "team", "good", "fifa", "pack", "ultimate", "packs", "drivers", "tots", "23", "list", "stranger", "opening", "x", "picks", "rewards", "stubs", "red", "monaco", "tier", "verstappen", "affinity", "ranked", "netflix", "squads", "icon", "review", "hole", "royale", "fut", "complete", "mlb", "21", "show", "f1", "player", "10", "top", "2022", "season", "best", "new", "challenge", "5", "things", "1", "world", "2020", "sports", "undisputed", "lebron", "shannon", "skip", "stephen", "hamilton", "lewis", "james", "trailer", "run", "home", "recap", "ad", "god", "old", "loss", "meme", "bucks", "henry", "year", "messi", "thierry", "fight", "card", "try", "perez", "draft", "windhorst", "sharpe", "games", "fastest", "reacts", "win", "nba", "broussard", "lakers", "us", "first", "shorts", "game", "get", "f1", "3", "vs", "nets", "moments", "https", "2021", "grand", "prix", "removed", "clippers", "shots", "trick", "diamonds", "cbs", "russell", "extended", "1v1", "ucl", "city", "westbrook", "mike", "golazo", "michael", "trout", "nuggets", "sportscenter", "premier", "goals", "funniest", "kawhi", "compilation", "done", "interview", "hours", "video", "race", "sports", "highlights", "league", "shorts", "moments", "man", "new", "2", "diamond", "dynasty", "perfect", "dude", "react", "22", "official", "99", "inning", "jalen", "pro", "mercedes", "think", "tips", "two", "playoffs", "impossible", "ovr", "24", "giant", "hidden", "tour", "expensive", "years", "11", "dad", "rose", "far", "wanted", "explained", "battle", "100", "need", "road", "money", "vs", "test", "taste", "2", "golf", "show", "football", "food", "21", "shorts", "mlb"], "Freq": [456.0, 438.0, 250.0, 538.0, 247.0, 264.0, 381.0, 235.0, 354.0, 242.0, 389.0, 202.0, 195.0, 353.0, 181.0, 178.0, 286.0, 144.0, 274.0, 157.0, 291.0, 131.0, 154.0, 141.0, 149.0, 261.0, 137.0, 135.0, 155.0, 128.0, 153.86801105796638, 148.95635111165726, 108.64332643459883, 93.55532932468553, 91.20798996090559, 87.5383027859088, 60.560443382949195, 62.13586334898153, 60.290113687884855, 58.32979420223307, 58.11647716797613, 59.52354323078604, 49.477457576417486, 41.033225904353365, 38.05824120425331, 37.71738236362834, 37.68686137234554, 34.32353397226827, 33.976957850770205, 33.62979558787169, 31.670273638879515, 30.388728315641597, 31.24130461363932, 27.49988398069629, 27.849749540545442, 26.479240444259425, 26.92409133908465, 28.91882661352159, 25.273513952499183, 25.48536563325503, 113.80122982826042, 297.9952104335616, 194.07954038695374, 196.4850006351725, 172.66933885502044, 62.76281044035469, 160.5220163540516, 93.16816851638461, 170.74983146622301, 257.88917374481883, 58.768689195779, 47.950543213490064, 167.754706563249, 118.33723399310122, 189.52372912692007, 89.76223215974998, 94.88473005045847, 75.49052823425987, 69.25136371359342, 59.4355323378 ...
