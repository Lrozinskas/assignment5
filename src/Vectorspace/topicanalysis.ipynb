# %%
import json
from gensim import corpora, models
import pyLDAvis.gensim_models
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download the NLTK stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# Specify the path to your watch history file
watch_history_file = '/home/lrozinskas/CS128/Data_folder/history/watch-history.json'

# Read the JSON data
with open(watch_history_file, 'r') as f:
    data = json.load(f)

# Extract titles from the data
titles = [entry['title'] for entry in data]

# Tokenize and preprocess the data, removing stopwords
stop_words = set(stopwords.words('english'))
stop_words.add('watched')
tokenized_titles = [word_tokenize(title.lower()) for title in titles]
filtered_tokenized_titles = [[word for word in tokens if word.isalnum() and word not in stop_words] for tokens in tokenized_titles]

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(filtered_tokenized_titles)
corpus = [dictionary.doc2bow(tokens) for tokens in filtered_tokenized_titles]

# Build the LDA model
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# Print the top words for each topic
topics = lda_model.print_topics(num_words=5)
for topic in topics:
    print(f"Topic {topic[0] + 1}: {topic[1]}")

# Visualize the topics using pyLDAvis
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/lrozinskas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/lrozinskas/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Topic 1: 0.039*"nba" + 0.025*"game" + 0.021*"lakers" + 0.019*"undisputed" + 0.016*"first"
# Topic 2: 0.033*"f1" + 0.023*"golf" + 0.015*"shorts" + 0.014*"10" + 0.013*"good"
# Topic 3: 0.031*"test" + 0.030*"taste" + 0.014*"food" + 0.014*"shorts" + 0.014*"stephen"
# Topic 4: 0.021*"diamond" + 0.020*"2021" + 0.019*"highlights" + 0.017*"grand" + 0.016*"prix"
# Topic 5: 0.035*"mlb" + 0.029*"show" + 0.027*"21" + 0.019*"team" + 0.018*"https"
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el9591407040856858882143714938" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el9591407040856858882143714938_data = {"mdsDat": {"x": [0.2593731350246193, -0.20971786990136024, -0.010084374404315994, 0.03906076124576045, -0.07863165196470377], "y": [-0.1524984426373098, -0.18808536993301164, 0.16874912460118055, 0.1301911510352152, 0.04164353693392579], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [22.573689693091495, 20.821183261621456, 20.15027391722204, 19.922739149763462, 16.53211397830155]}, "tinfo": {"Term": ["nba", "mlb", "show", "test", "f1", "21", "taste", "game", "lakers", "diamond", "golf", "undisputed", "2021", "team", "https", "highlights", "grand", "prix", "10", "first", "lebron", "dynasty", "food", "stephen", "good", "shannon", "take", "video", "full", "international", "nba", "lakers", "undisputed", "shannon", "take", "video", "full", "skip", "removed", "things", "clippers", "suns", "bad", "stranger", "paul", "chris", "nets", "official", "big", "diamonds", "monaco", "broussard", "old", "jalen", "finals", "kobe", "bucks", "tried", "loss", "warriors", "jump", "game", "first", "win", "4", "part", "2023", "highlights", "2020", "shorts", "2", "3", "5", "show", "21", "mlb", "team", "https", "dynasty", "lebron", "fifa", "battle", "player", "packs", "sidemen", "23", "list", "anthony", "stubs", "picks", "program", "inning", "1v1", "flight", "tier", "bob", "davis", "affinity", "greatest", "squads", "god", "euro", "tips", "ultimate", "espn", "sports", "make", "new", "james", "tots", "best", "perfect", "dude", "2", "shorts", "fc", "get", "10", "good", "hamilton", "lewis", "formula", "recap", "record", "5v5", "meme", "played", "course", "hole", "match", "perez", "gm", "ricciardo", "trout", "name", "golfer", "fastest", "break", "interview", "daniel", "likes", "love", "lewishamilton", "find", "rick", "tour", "par", "golf", "f1", "rankings", "fishing", "top", "moments", "driver", "life", "biggest", "shorts", "play", "basketball", "car", "season", "world", "vs", "1", "2022", "ever", "new", "2020", "best", "us", "2021", "diamond", "grand", "prix", "race", "drivers", "react", "players", "spent", "cbs", "trailer", "cup", "russell", "99", "extended", "ucl", "fight", "henry", "westbrook", "thierry", "golazo", "injury", "club", "madrid", "horizon", "qualifying", "plays", "forza", "2nd", "many", "lando", "money", "highlights", "reacts", "insane", "2022", "challenge", "shorts", "5", "pack", "world", "sports", "f1", "1", "vs", "2", "best", "test", "taste", "food", "stephen", "international", "worst", "fast", "opening", "hot", "rewards", "frozen", "trash", "review", "foods", "fut", "fancy", "sportscenter", "24", "huge", "place", "mario", "lap", "reacting", "wings", "pizza", "champions", "ones", "2019", "update", "spicy", "12", "xp", "trick", "22", "super", "shots", "perfect", "dude", "shorts", "best", "pack", "1", "16x9"], "Freq": [517.0, 436.0, 363.0, 302.0, 472.0, 337.0, 291.0, 375.0, 279.0, 246.0, 291.0, 254.0, 233.0, 232.0, 228.0, 346.0, 200.0, 193.0, 171.0, 250.0, 169.0, 166.0, 140.0, 137.0, 150.0, 152.0, 147.0, 146.0, 143.0, 116.0, 516.2905237403083, 278.77267742201184, 254.25392980908782, 151.35840243381153, 147.166921146993, 145.9098320187627, 142.4562648424171, 135.93835593821268, 91.4544743648105, 81.4535866767119, 73.28209599206048, 59.457780346358504, 53.98560710067045, 51.74145906307956, 48.76512466821282, 48.80409084121425, 46.36569780238176, 47.2173816700473, 46.4984364571319, 62.09849894358172, 43.66469133064754, 39.49081400346472, 36.64024087520431, 36.236107063662644, 36.05064690260747, 35.8765175960815, 34.70242479587, 35.218598819977274, 36.52356672955705, 33.90565630733363, 116.58736301884801, 329.0402372517565, 218.57839153125497, 85.03134450616471, 70.1337763027459, 55.52930826211309, 59.314879448313604, 119.6139352316095, 62.46723785805443, 109.80470601855359, 75.7809046735656, 63.154350100943475, 50.97784797063525, 363.1054959495555, 337.111157782401, 435.6846616294925, 231.9840598304393, 228.13117140633202, 165.97075603754578, 168.51877554468066, 129.65858070275 ...
